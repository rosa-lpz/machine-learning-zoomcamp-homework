# %% [markdown]
# # Deep Learning - Homework-07
#
# > **Note**: it's very likely that in this homework your answers won't match
# > the options exactly. That's okay and expected. Select the option that's
# > closest to your solution.
# > If it's exactly in between two options, select the higher value.
#
# In this homework, we'll build a model for classifying various hair types.
# For this, we will use the Hair Type dataset that was obtained from
# [Kaggle](https://www.kaggle.com/datasets/kavyasreeb/hair-type-dataset)
# and slightly rebuilt.

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import zipfile
import os

# %% [markdown]
# ## Dataset
#
# In this homework, we'll build a model for classifying various hair types.
# For this, we will use the Hair Type dataset that was obtained from
# [Kaggle](https://www.kaggle.com/datasets/kavyasreeb/hair-type-dataset)
# and slightly rebuilt.
#
# You can download the target dataset for this homework from
# [here](https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip):
#
# ```bash
# wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip
# unzip data.zip
# ```

# %%
file_url = 'https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip'
file ='data.zip'

# %%
# Download dataset zip file
# !wget $file_url
# Out:
# --2025-12-02 12:08:04--  https://github.com/SVizor42/ML_Zoomcamp/releases/download/straight-curly-data/data.zip
# Resolving github.com (github.com)... 140.82.113.3
# connected. to github.com (github.com)|140.82.113.3|:443...
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/405934815/e712cf72-f851-44e0-9c05-e711624af985?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T19%3A58%3A53Z&rscd=attachment%3B+filename%3Ddata.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T18%3A58%3A28Z&ske=2025-12-02T19%3A58%3A53Z&sks=b&skv=2018-11-09&sig=H832oZDITypKq33SeYeFIoAXCN0tDi7Odd3DO7dsYVs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDcwNDI2MiwibmJmIjoxNzY0NzAyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.APcBcdmeBLGD0ZDJj8rbFTL5nkDVRBaHvEoeiAhhcWU&response-content-disposition=attachment%3B%20filename%3Ddata.zip&response-content-type=application%2Foctet-stream [following]
# --2025-12-02 12:08:05--  https://release-assets.githubusercontent.com/github-production-release-asset/405934815/e712cf72-f851-44e0-9c05-e711624af985?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T19%3A58%3A53Z&rscd=attachment%3B+filename%3Ddata.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T18%3A58%3A28Z&ske=2025-12-02T19%3A58%3A53Z&sks=b&skv=2018-11-09&sig=H832oZDITypKq33SeYeFIoAXCN0tDi7Odd3DO7dsYVs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDcwNDI2MiwibmJmIjoxNzY0NzAyNDYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.APcBcdmeBLGD0ZDJj8rbFTL5nkDVRBaHvEoeiAhhcWU&response-content-disposition=attachment%3B%20filename%3Ddata.zip&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# connected. to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443...
# HTTP request sent, awaiting response... 200 OK
# Length: 102516572 (98M) [application/octet-stream]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]  97.77M  16.2MB/s    in 5.9s
#
# 2025-12-02 12:08:11 (16.4 MB/s) - ‘data.zip’ saved [102516572/102516572]

# %%
zip_file_path ='data.zip'
#extract_folder='data'
# Get the current working directory (current folder where the script is running)
extract_folder = os.getcwd()

# Open the zip file and extract all its contents
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

# Make sure the extraction folder exists
if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print(f"Extracted all files to {extract_folder}")
except FileNotFoundError:
    print(f"Error: The file {zip_file_path} was not found.")
except zipfile.BadZipFile:
    print(f"Error: The file {zip_file_path} is not a valid zip file.")
except PermissionError:
    print(f"Error: Permission denied when accessing {zip_file_path} or {extract_folder}.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Extracted all files to /home/rllz-d3/Repositories/GitHub/training/bootcamps/machine-learning-zoomcamp-homework/08-deep-learning

# %%
git rm
